# %% [markdown]
#  # INTRODUCTION

# %% [markdown]
# *The main idea of creating this notebook is to use it for a Capstone project*

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Hello Capstone Project Course!
